# %%
# Imports
import stocker
from stocker import Stocker

# %%
# Pulling apple stock Data
aapl = Stocker('AAPL')
# Out:
# AAPL Stocker Initialized. Data covers 1980-12-12 00:00:00 to 2018-03-27 00:00:00.

# %%
# Pulling amazon stock data
amzn = Stocker('AMZN')
# Out:
# AMZN Stocker Initialized. Data covers 1997-05-16 00:00:00 to 2018-03-27 00:00:00.

# %%
# Pulling netflix stock data
nflx = Stocker('NFLX')
# Out:
# NFLX Stocker Initialized. Data covers 2002-05-23 00:00:00 to 2018-03-27 00:00:00.

# %%
# Pulling tesla stock data
tsla = Stocker('TSLA')
# Out:
# TSLA Stocker Initialized. Data covers 2010-06-29 00:00:00 to 2018-03-27 00:00:00.

# %%
# Plot apple adj closing price
aapl.plot_stock()
# Out:
# Maximum Adj. Close = 181.72 on 2018-03-12 00:00:00.
# Minimum Adj. Close = 0.16 on 1982-07-08 00:00:00.
# Current Adj. Close = 168.34 on 2018-03-27 00:00:00.

# %%
# Plotting amazon adj close
amzn.plot_stock()
# Out:
# Maximum Adj. Close = 1598.39 on 2018-03-12 00:00:00.
# Minimum Adj. Close = 1.40 on 1997-05-22 00:00:00.
# Current Adj. Close = 1497.05 on 2018-03-27 00:00:00.

# %%
# Plotting tesla adj closing price
tsla.plot_stock()
# Out:
# Maximum Adj. Close = 385.00 on 2017-09-18 00:00:00.
# Minimum Adj. Close = 15.80 on 2010-07-07 00:00:00.
# Current Adj. Close = 279.18 on 2018-03-27 00:00:00.

# %%
# Plotting netflix adj closing price
nflx.plot_stock()
# Out:
# Maximum Adj. Close = 331.44 on 2018-03-09 00:00:00.
# Minimum Adj. Close = 0.37 on 2002-10-09 00:00:00.
# Current Adj. Close = 300.69 on 2018-03-27 00:00:00.

# %%
# Apple prophet model
aapl_data = aapl.create_prophet_model(days=2000)
# Out:
# Predicted Price on 2023-09-17 00:00:00 = $373.43

# %%
#Apple Prediction
aapl.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $207.27.
# Actual price on    2018-03-23 00:00:00 = $164.94.
#
# Average Absolute Error on Training Data = $2.83.
# Average Absolute Error on Testing  Data = $11.80.
#
# When the model predicted an increase, the price increased 48.59% of the time.
# When the model predicted a  decrease, the price decreased  43.66% of the time.
#
# The actual value was within the 80% confidence interval 59.84% of the time.

# %%
# Apple changepoint prior scale
aapl.changepoint_prior_analysis(changepoint_priors = [.001, .05, .1, .2])

# %%
# Apple training and testing curves
aapl.changepoint_prior_validation(start_date = '2015-03-27', end_date = '2018-03-27', changepoint_priors = [.001, .05, .1, .2])
# Out:
# Validation Range 2015-03-27 00:00:00 to 2018-03-27 00:00:00.
#
#      cps  train_err  train_range   test_err  test_range
# 0  0.001  11.559111    35.317333  21.180272   35.358782
# 1  0.050   1.838485     6.157416  91.847669  204.103071
# 2  0.100   1.740549     5.874913  85.370409  248.678979
# 3  0.200   1.590864     5.358523  94.134864  463.531243

# %%
# Apple prediction
aapl.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $195.35.
# Actual price on    2018-03-23 00:00:00 = $164.94.
#
# Average Absolute Error on Training Data = $1.78.
# Average Absolute Error on Testing  Data = $7.55.
#
# When the model predicted an increase, the price increased 47.53% of the time.
# When the model predicted a  decrease, the price decreased  43.02% of the time.
#
# The actual value was within the 80% confidence interval 97.19% of the time.

# %%
# Apple prediction vs buy/hold 
aapl.evaluate_prediction(nshares=1000)
# Out:
# /Users/johnmcgraw/Documents/Files/stocker.py:779: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_pred_increase["pred_profit"] = prediction_profit
# You played the stock market in AAPL from 2017-03-27 00:00:00 to 2018-03-27 00:00:00 with 1000 shares.
#
# When the model predicted an increase, the price increased 47.53% of the time.
# When the model predicted a  decrease, the price decreased  43.02% of the time.
#
# The total profit using the Prophet model = $1730.25.
# The Buy and Hold strategy profit =         $25201.15.
#
# Thanks for playing the stock market!

# %%
# Amazon prophet model
amzn_data = amzn.create_prophet_model(days=2000)
# Out:
# Predicted Price on 2023-09-17 00:00:00 = $7088.64

# %%
# Amazon prediction
amzn.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $1055.83.
# Actual price on    2018-03-23 00:00:00 = $1495.56.
#
# Average Absolute Error on Training Data = $17.07.
# Average Absolute Error on Testing  Data = $137.77.
#
# When the model predicted an increase, the price increased 56.96% of the time.
# When the model predicted a  decrease, the price decreased  41.11% of the time.
#
# The actual value was within the 80% confidence interval 57.83% of the time.

# %%
# Amazon changepoint prior scale
amzn.changepoint_prior_analysis(changepoint_priors = [.001, .05, .1, .2])

# %%
# Amazon training and testing curves
amzn.changepoint_prior_validation(start_date = '2015-03-27', end_date = '2018-03-27', changepoint_priors = [.001, .05, .1, .2])
# Out:
# Validation Range 2015-03-27 00:00:00 to 2018-03-27 00:00:00.
#
#      cps  train_err  train_range    test_err   test_range
# 0  0.001  21.270612    79.908501  345.841004    79.897234
# 1  0.050  11.013719    35.596147  411.900224   512.893958
# 2  0.100   8.674213    28.892951  330.018543  1189.921365
# 3  0.200   8.234384    27.321709  310.578978  1615.216392

# %%
# Amazon prediction
amzn.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $1052.48.
# Actual price on    2018-03-23 00:00:00 = $1495.56.
#
# Average Absolute Error on Training Data = $12.32.
# Average Absolute Error on Testing  Data = $144.82.
#
# When the model predicted an increase, the price increased 60.13% of the time.
# When the model predicted a  decrease, the price decreased  46.67% of the time.
#
# The actual value was within the 80% confidence interval 86.75% of the time.

# %%
# Amazon prediction
amzn.evaluate_prediction(nshares=1000)
# Out:
# /Users/johnmcgraw/Documents/Files/stocker.py:779: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_pred_increase["pred_profit"] = prediction_profit
# You played the stock market in AMZN from 2017-03-27 00:00:00 to 2018-03-27 00:00:00 with 1000 shares.
#
# When the model predicted an increase, the price increased 60.13% of the time.
# When the model predicted a  decrease, the price decreased  46.67% of the time.
#
# The total profit using the Prophet model = $590810.00.
# The Buy and Hold strategy profit =         $648740.00.
#
# Thanks for playing the stock market!

# %%
# Tesla prophet model
tsla_data = amzn.create_prophet_model(days=2000)
# Out:
# Predicted Price on 2023-09-17 00:00:00 = $6972.70

# %%
# Tesla prediciton
tsla.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $423.44.
# Actual price on    2018-03-23 00:00:00 = $301.54.
#
# Average Absolute Error on Training Data = $12.47.
# Average Absolute Error on Testing  Data = $30.71.
#
# When the model predicted an increase, the price increased 45.96% of the time.
# When the model predicted a  decrease, the price decreased  40.91% of the time.
#
# The actual value was within the 80% confidence interval 67.20% of the time.

# %%
# Tesla changepoint error scale
tsla.changepoint_prior_analysis(changepoint_priors = [.001, .05, .1, .2])

# %%
# Tesla training and testing curve
tsla.changepoint_prior_validation(start_date = '2015-03-27', end_date = '2018-03-27', changepoint_priors = [.001, .05, .1, .2])
# Out:
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.
# Validation Range 2015-03-27 00:00:00 to 2018-03-27 00:00:00.
#
#      cps  train_err  train_range    test_err   test_range
# 0  0.001  20.842807    70.486945  158.184025    70.541088
# 1  0.050   8.804835    29.469887   69.976488   387.008911
# 2  0.100   6.794704    22.784679   79.687796   905.549061
# 3  0.200   6.040942    20.331630  162.409112  1485.825401

# %%
# Tesla prediciton
tsla.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $332.17.
# Actual price on    2018-03-23 00:00:00 = $301.54.
#
# Average Absolute Error on Training Data = $9.11.
# Average Absolute Error on Testing  Data = $55.26.
#
# When the model predicted an increase, the price increased 42.54% of the time.
# When the model predicted a  decrease, the price decreased  40.00% of the time.
#
# The actual value was within the 80% confidence interval 80.00% of the time.

# %%
# Tesla prediction 
tsla.evaluate_prediction(nshares=1000)
# Out:
# /Users/johnmcgraw/Documents/Files/stocker.py:779: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_pred_increase["pred_profit"] = prediction_profit
# You played the stock market in TSLA from 2017-03-27 00:00:00 to 2018-03-27 00:00:00 with 1000 shares.
#
# When the model predicted an increase, the price increased 42.54% of the time.
# When the model predicted a  decrease, the price decreased  40.00% of the time.
#
# The total profit using the Prophet model = $-75385.00.
# The Buy and Hold strategy profit =         $31320.00.
#
# Thanks for playing the stock market!

# %%
# Netflix prophet model
nflx_data = amzn.create_prophet_model(days=2000)
# Out:
# Predicted Price on 2023-09-17 00:00:00 = $6972.70

# %%
# Netflix prediciton
nflx.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $267.25.
# Actual price on    2018-03-23 00:00:00 = $300.94.
#
# Average Absolute Error on Training Data = $4.87.
# Average Absolute Error on Testing  Data = $33.33.
#
# When the model predicted an increase, the price increased 54.36% of the time.
# When the model predicted a  decrease, the price decreased  50.00% of the time.
#
# The actual value was within the 80% confidence interval 16.00% of the time.

# %%
# Netflix changepoint prior 
nflx.changepoint_prior_analysis(changepoint_priors = [.001, .05, .1, .2])
# Out:
# WARNING:fbprophet.models:Optimization terminated abnormally. Falling back to Newton.

# %%
# Netflix training and testing curves
nflx.changepoint_prior_validation(start_date = '2015-03-27', end_date = '2018-03-27', changepoint_priors = [.001, .05, .1, .2])
# Out:
# Validation Range 2015-03-27 00:00:00 to 2018-03-27 00:00:00.
#
#      cps  train_err  train_range   test_err  test_range
# 0  0.001   5.973944    21.244585  37.118080   21.172023
# 1  0.050   2.400267     7.605658  95.024219   70.011196
# 2  0.100   1.645218     5.395806  93.065280  247.894778
# 3  0.200   1.316253     4.514950  95.269099  466.800035

# %%
# Netflix prediction
nflx.evaluate_prediction()
# Out:
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $248.84.
# Actual price on    2018-03-23 00:00:00 = $300.94.
#
# Average Absolute Error on Training Data = $3.82.
# Average Absolute Error on Testing  Data = $24.73.
#
# When the model predicted an increase, the price increased 56.11% of the time.
# When the model predicted a  decrease, the price decreased  53.62% of the time.
#
# The actual value was within the 80% confidence interval 84.40% of the time.

# %%
# Tesla predictied vs Buy/Hold Profits
tsla.evaluate_prediction(nshares=1000)
# Out:
# /Users/johnmcgraw/Documents/Files/stocker.py:779: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_pred_increase["pred_profit"] = prediction_profit
# You played the stock market in TSLA from 2017-03-27 00:00:00 to 2018-03-27 00:00:00 with 1000 shares.
#
# When the model predicted an increase, the price increased 42.54% of the time.
# When the model predicted a  decrease, the price decreased  40.00% of the time.
#
# The total profit using the Prophet model = $-75385.00.
# The Buy and Hold strategy profit =         $31320.00.
#
# Thanks for playing the stock market!

# %%
#Creating dataframes
aapl_data = aapl.make_df('2011-12-06', '2018-03-27')
amzn_data = amzn.make_df('2011-12-06', '2018-03-27')
tsla_data = tsla.make_df('2011-12-06', '2018-03-27')
nflx_data = nflx.make_df('2011-12-06', '2018-03-27')

# %%
# Preping Data
aapl_data = aapl_data[['Date','Open', 'High','Low', 'Close','Adj. Close', 'Volume']]
amzn_data = amzn_data[['Date','Open', 'High','Low', 'Close','Adj. Close', 'Volume']]
tsla_data = tsla_data[['Date','Open', 'High','Low', 'Close','Adj. Close', 'Volume']]
nflx_data = nflx_data[['Date','Open', 'High','Low', 'Close','Adj. Close', 'Volume']]

# %%
# Root mean predicitons
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.style
import matplotlib as mpl
mpl.style.use('ggplot')

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20, 10

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))



aapl_data['Date'] = pd.to_datetime(aapl_data.Date, format='%Y-%m-%d')
aapl_data.index = aapl_data['Date']

amzn_data['Date'] = pd.to_datetime(amzn_data.Date, format='%Y-%m-%d')
amzn_data.index = amzn_data['Date']

tsla_data['Date'] = pd.to_datetime(tsla_data.Date, format='%Y-%m-%d')
tsla_data.index = tsla_data['Date']

nflx_data['Date'] = pd.to_datetime(nflx_data.Date, format='%Y-%m-%d')
nflx_data.index = nflx_data['Date']

# %%
# Creating Apple dataframe with date and the target variable

apple = aapl_data.sort_index(ascending=True, axis=0)
apple_data = pd.DataFrame(index=range(0,len(aapl_data)),columns=['Date', 'Adj. Close'])

for i in range(0,len(apple)):
    apple_data['Date'][i]= apple['Date'][i]
    apple_data['Adj. Close'][i]= apple['Adj. Close'][i]
    
train = apple_data[:1000]
test = apple_data[1000:]
    
apple_num = test.shape[0]
    
train['Date'].min(), train['Date'].max(), test['Date'].min(), test['Date'].max()
    
prediction= []
for i in range(0,apple_num):
    x = train['Adj. Close'][len(train)-924+i:].sum()+ sum(prediction)
    y = x/apple_num
    prediction.append(y)

# %%
# Root mean
root_mean = np.sqrt(np.mean(np.power((np.array(test['Adj. Close'])-prediction),2)))
print(root_mean)
# Out:
# 51.33827428805447

# %%
# Root mean graph
test['Predictions']=0
test['Predictions']= prediction
plt.plot(train['Adj. Close'])
plt.plot(test[['Adj. Close', 'Predictions']])
# Out:
# <ipython-input-98-fa520f5fd966>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']=0
# <ipython-input-98-fa520f5fd966>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']= prediction
# ...

# %%
# Creating Amazon dataframe with date and the target variable
amazon = amzn_data.sort_index(ascending=True, axis=0)
amazon_data = pd.DataFrame(index=range(0,len(amzn_data)),columns=['Date', 'Adj. Close'])

for i in range(0,len(amazon)):
    amazon_data['Date'][i]= amazon['Date'][i]
    amazon_data['Adj. Close'][i]= amazon['Adj. Close'][i]
    
train = amazon_data[:1000]
test = amazon_data[1000:]
    
amazon_num = test.shape[0]
    
train['Date'].min(), train['Date'].max(), test['Date'].min(), test['Date'].max()
    
prediction= []
for i in range(0,amazon_num):
    x = train['Adj. Close'][len(train)-924+i:].sum()+ sum(prediction)
    y = x/amazon_num
    prediction.append(y)

# %%
root_mean = np.sqrt(np.mean(np.power((np.array(test['Adj. Close'])-prediction),2)))
print(root_mean)
# Out:
# 212.48417939363847

# %%
test['Predictions']=0
test['Predictions']= prediction
plt.plot(train['Adj. Close'])
plt.plot(test[['Adj. Close', 'Predictions']])
# Out:
# <ipython-input-85-febf8c0d6578>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']=0
# <ipython-input-85-febf8c0d6578>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']= prediction
# ...

# %%
# Creating Tesla dataframe with date and the target variable
tesla = tsla_data.sort_index(ascending=True, axis=0)
tesla_data = pd.DataFrame(index=range(0,len(tsla_data)),columns=['Date', 'Adj. Close'])

for i in range(0,len(tesla)):
    tesla_data['Date'][i]= tesla['Date'][i]
    tesla_data['Adj. Close'][i]= tesla['Adj. Close'][i]
    
train = tesla_data[:1000]
test = tesla_data[1000:]
    
tesla_num = test.shape[0]
train['Date'].min(), train['Date'].max(), test['Date'].min(), test['Date'].max()
    
prediction= []
for i in range(0,tesla_num):
    x = train['Adj. Close'][len(train)-924+i:].sum()+ sum(prediction)
    y = x/tesla_num
    prediction.append(y)

# %%
root_mean = np.sqrt(np.mean(np.power((np.array(test['Adj. Close'])-prediction),2)))
print(root_mean)
# Out:
# 112.75016321842948

# %%
test['Predictions']=0
test['Predictions']= prediction
plt.plot(train['Adj. Close'])
plt.plot(test[['Adj. Close', 'Predictions']])
# Out:
# <ipython-input-88-febf8c0d6578>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']=0
# <ipython-input-88-febf8c0d6578>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']= prediction
# ...

# %%
# Creating Netflix dataframe with date and the target variable
netflix = nflx_data.sort_index(ascending=True, axis=0)
netflix_data = pd.DataFrame(index=range(0,len(nflx_data)),columns=['Date', 'Adj. Close'])

for i in range(0,len(netflix)):
    netflix_data['Date'][i]= netflix['Date'][i]
    netflix_data['Adj. Close'][i]= netflix['Adj. Close'][i]
    
train = netflix_data[:1000]
test = netflix_data[1000:]
    
netflix_num = test.shape[0]
train['Date'].min(), train['Date'].max(), test['Date'].min(), test['Date'].max()
    
prediction= []
for i in range(0,netflix_num):
    x = train['Adj. Close'][len(train)-924+i:].sum()+ sum(prediction)
    y = x/netflix_num
    prediction.append(y)

# %%
root_mean = np.sqrt(np.mean(np.power((np.array(test['Adj. Close'])-prediction),2)))
print(root_mean)
# Out:
# 44.14341697900445

# %%
test['Predictions']=0
test['Predictions']= prediction
plt.plot(train['Adj. Close'])
plt.plot(test[['Adj. Close', 'Predictions']])
# Out:
# <ipython-input-94-febf8c0d6578>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']=0
# <ipython-input-94-febf8c0d6578>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']= prediction
# ...

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression

# %%
# Apple Linear Agression
apple = aapl_data.sort_index(ascending=True, axis=0)
apple_data = pd.DataFrame(index=range(0,len(aapl_data)),columns=['Close', 'Adj. Close'])

for i in range(0,len(apple)):
    apple_data['Close'][i]= apple['Close'][i]
    apple_data['Adj. Close'][i]= apple['Adj. Close'][i]
    
train = apple_data[:1000]
test = apple_data[1000:]

x_train = train.drop('Adj. Close', axis=1)
y_train = train['Adj. Close']
x_test = test.drop('Adj. Close', axis=1)
y_test = test['Adj. Close']

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(x_test)
root_mean = np.sqrt(np.mean(np.power((np.array(y_test)-np.array(prediction)),2)))
print(root_mean)
# Out:
# 41.67326091912685

# %%
test['Predictions']=0
test['Predictions']= prediction
plt.plot(train['Adj. Close'])
plt.plot(test[['Adj. Close', 'Predictions']])
# Out:
# <ipython-input-113-febf8c0d6578>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']=0
# <ipython-input-113-febf8c0d6578>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']= prediction
# ...

# %%
# Amazon Linear Agression
amazon = amzn_data.sort_index(ascending=True, axis=0)
amazon_data = pd.DataFrame(index=range(0,len(amzn_data)),columns=['Close', 'Adj. Close'])

for i in range(0,len(amazon)):
    amazon_data['Close'][i]= amazon['Close'][i]
    amazon_data['Adj. Close'][i]= amazon['Adj. Close'][i]
    
train = amazon_data[:1000]
test = amazon_data[1000:]

x_train = train.drop('Adj. Close', axis=1)
y_train = train['Adj. Close']
x_test = test.drop('Adj. Close', axis=1)
y_test = test['Adj. Close']

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(x_test)
root_mean = np.sqrt(np.mean(np.power((np.array(y_test)-np.array(prediction)),2)))
print(root_mean)
# Out:
# 2.383740575623908e-13

# %%
test['Predictions']=0
test['Predictions']= prediction
plt.plot(train['Adj. Close'])
plt.plot(test[['Adj. Close', 'Predictions']])
# Out:
# <ipython-input-117-febf8c0d6578>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']=0
# <ipython-input-117-febf8c0d6578>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']= prediction
# ...

# %%
# Tesla Linear Agression
tesla = tsla_data.sort_index(ascending=True, axis=0)
tesla_data = pd.DataFrame(index=range(0,len(tsla_data)),columns=['Close', 'Adj. Close'])

for i in range(0,len(tesla)):
    tesla_data['Close'][i]= tesla['Close'][i]
    tesla_data['Adj. Close'][i]= tesla['Adj. Close'][i]
    
train = tesla_data[:1000]
test = tesla_data[1000:]

x_train = train.drop('Adj. Close', axis=1)
y_train = train['Adj. Close']
x_test = test.drop('Adj. Close', axis=1)
y_test = test['Adj. Close']

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(x_test)
root_mean = np.sqrt(np.mean(np.power((np.array(y_test)-np.array(prediction)),2)))
print(root_mean)
# Out:
# 0.0

# %%
test['Predictions']=0
test['Predictions']= prediction
plt.plot(train['Adj. Close'])
plt.plot(test[['Adj. Close', 'Predictions']])
# Out:
# <ipython-input-124-febf8c0d6578>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']=0
# <ipython-input-124-febf8c0d6578>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']= prediction
# ...

# %%
# Netflix Linear Agression
netflix = nflx_data.sort_index(ascending=True, axis=0)
netflix_data = pd.DataFrame(index=range(0,len(nflx_data)),columns=['Close', 'Adj. Close'])

for i in range(0,len(netflix)):
    netflix_data['Close'][i]= netflix['Close'][i]
    netflix_data['Adj. Close'][i]= netflix['Adj. Close'][i]
    
train = netflix_data[:1000]
test = netflix_data[1000:]

x_train = train.drop('Adj. Close', axis=1)
y_train = train['Adj. Close']
x_test = test.drop('Adj. Close', axis=1)
y_test = test['Adj. Close']

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(x_test)
root_mean = np.sqrt(np.mean(np.power((np.array(y_test)-np.array(prediction)),2)))
print(root_mean)
# Out:
# 121.86486200278013

# %%
test['Predictions']=0
test['Predictions']= prediction
plt.plot(train['Adj. Close'])
plt.plot(test[['Adj. Close', 'Predictions']])
# Out:
# <ipython-input-128-febf8c0d6578>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']=0
# <ipython-input-128-febf8c0d6578>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions']= prediction
# ...

# %%
# Initial imports
import numpy as np
import pandas as pd
from pathlib import Path

# %matplotlib inline

from numpy.random import seed

seed(1)
from tensorflow import random

random.set_seed(2)

# %%
apple_df = pd.read_csv(
    Path("aapl.csv"),
    index_col='Date',
    infer_datetime_format=True,
    parse_dates=True,
)
apple_df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-09-14  114.720001  115.930000  112.800003  115.360001  114.622765
# 2020-09-15  118.330002  118.830002  113.610001  115.540001  114.801620
# 2020-09-16  115.230003  116.000000  112.040001  112.129997  111.413406
# 2020-09-17  109.720001  112.199997  108.709999  110.339996  109.634850
# 2020-09-18  110.400002  110.879997  106.089996  106.839996  106.157211
#
#                Volume
# Date
# 2020-09-14  140150100
# 2020-09-15  184642000
# 2020-09-16  154679000
# 2020-09-17  178011000
# 2020-09-18  287104900

# %%
def window_data(df, window, feature_col_number, target_col_number):
 
    X = []
    y = []
    for i in range(len(df) - window):
        features = df.iloc[i : (i + window), feature_col_number]
        target = df.iloc[(i + window), target_col_number]
        X.append(features)
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Creating the features (X) and target (y) data using the window_data() function.
window_size = 5

feature_column = 2
target_column = 2
X, y = window_data(apple_df, window_size, feature_column, target_column)
print (f"X sample values:\n{X[:5]} \n")
print (f"y sample values:\n{y[:5]}")
# Out:
# X sample values:
# [[112.800003 113.610001 112.040001 108.709999 106.089996]
#  [113.610001 112.040001 108.709999 106.089996 103.099998]
#  [112.040001 108.709999 106.089996 103.099998 109.160004]
#  [108.709999 106.089996 103.099998 109.160004 106.769997]
#  [106.089996 103.099998 109.160004 106.769997 105.      ]]
#
# y sample values:
# [[103.099998]
#  [109.160004]
#  [106.769997]
#  [105.      ]
#  [107.669998]]

# %%
# Use 70% of the data for training and the remainder for testing
split = int(0.7 * len(X))
X_train = X[: split]
X_test = X[split:]
y_train = y[: split]
y_test = y[split:]

# %%
# Use the MinMaxScaler to scale data between 0 and 1.
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(X)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
scaler.fit(y)
y_train = scaler.transform(y_train)
y_test = scaler.transform(y_test)

# %%
# Reshape the features for the model
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
print (f"X_train sample values:\n{X_train[:5]} \n")
print (f"X_test sample values:\n{X_test[:5]}")
# Out:
# X_train sample values:
# [[[0.18912078]
#   [0.20491329]
#   [0.17430304]
#   [0.10937806]
#   [0.05829592]]
#
#  [[0.20491329]
#   [0.17430304]
#   [0.10937806]
#   [0.05829592]
#   [0.        ]]
#
#  [[0.17430304]
#   [0.10937806]
#   [0.05829592]
#   [0.        ]
#   [0.1181518 ]]
#
#  [[0.10937806]
#   [0.05829592]
#   [0.        ]
#   [0.1181518 ]
#   [0.07155389]]
#
#  [[0.05829592]
#   [0.        ]
#   [0.1181518 ]
#   [0.07155389]
#   [0.0370443 ]]]
#
# X_test sample values:
# [[[0.43107819]
#   [0.44531105]
#   [0.45271986]
#   [0.45466952]
#   [0.42854365]]
#
#  [[0.44531105]
#   [0.45271986]
#   [0.45466952]
#   [0.42854365]
#   [0.41821027]]
#
#  [[0.45271986]
#   [0.45466952]
#   [0.42854365]
#   [0.41821027]
#   [0.40631709]]
#
#  [[0.45466952]
#   [0.42854365]
#   [0.41821027]
#   [0.40631709]
#   [0.40846178]]
#
#  [[0.42854365]
#   [0.41821027]
#   [0.40631709]
#   [0.40846178]
#   [0.39052444]]]

# %%
# Import required Keras modules
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
# Define the LSTM RNN model.
model = Sequential()

number_units = 5
dropout_fraction = 0.2

# Layer 1
model.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_train.shape[1], 1))
    )
model.add(Dropout(dropout_fraction))
# Layer 2
model.add(LSTM(units=number_units, return_sequences=True))
model.add(Dropout(dropout_fraction))
# Layer 3
model.add(LSTM(units=number_units))
model.add(Dropout(dropout_fraction))
# Output layer
model.add(Dense(1))

# %%
# Compile the model
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
# Summarize the model
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 5, 5)              140
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 5)              0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 5)              220
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5)              0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 5)                 220
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5)                 0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 6
# ...

# %%
# Train the model
model.fit(X_train, y_train, epochs=10, shuffle=False, batch_size=1, verbose=1)
# Out:
# Epoch 1/10
# 173/173 [==============================] - 7s 9ms/step - loss: 0.0292
# Epoch 2/10
# 173/173 [==============================] - 1s 9ms/step - loss: 0.0303
# Epoch 3/10
# 173/173 [==============================] - ETA: 0s - loss: 0.029 - 1s 9ms/step - loss: 0.0288
# Epoch 4/10
# 173/173 [==============================] - 1s 8ms/step - loss: 0.0257
# Epoch 5/10
# 173/173 [==============================] - 1s 8ms/step - loss: 0.0247
# Epoch 6/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.0195
# Epoch 7/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.0198
# Epoch 8/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.0152
# Epoch 9/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.0144
# Epoch 10/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.0130

# %%
# Evaluate the model
model.evaluate(X_test, y_test)
# Out:
# 3/3 [==============================] - 2s 4ms/step - loss: 0.0372
# 0.03720828890800476

# %%
# Make some predictions
predicted = model.predict(X_test)

# %%
# Recover the original prices instead of the scaled version
predicted_prices = scaler.inverse_transform(predicted)
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
# Create a DataFrame of Real and Predicted values
apple_stocks = pd.DataFrame({
    "Real": real_prices.ravel(),
    "Predicted": predicted_prices.ravel()
    }, index = apple_df.index[-len(real_prices): ])
apple_stocks.head()
# Out:
#                   Real   Predicted
# Date
# 2021-05-28  124.550003  127.426620
# 2021-06-01  123.940002  127.508728
# 2021-06-02  124.050003  127.402405
# 2021-06-03  123.129997  127.152199
# 2021-06-04  123.849998  126.787582

# %%
# Plot the real vs predicted prices as a line chart
apple_stocks.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
amazon_df = pd.read_csv(
    Path("amzn.csv"),
    index_col='Date',
    infer_datetime_format=True,
    parse_dates=True,
)
amazon_df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-09-14  3172.939941  3187.389893  3096.000000  3102.969971  3102.969971
# 2020-09-15  3136.159912  3175.020020  3108.919922  3156.129883  3156.129883
# 2020-09-16  3179.989990  3187.239990  3074.149902  3078.100098  3078.100098
# 2020-09-17  3009.250000  3029.429932  2972.550049  3008.729980  3008.729980
# 2020-09-18  3031.739990  3037.800049  2905.540039  2954.909912  2954.909912
#
#              Volume
# Date
# 2020-09-14  4529600
# 2020-09-15  4021500
# 2020-09-16  4512200
# 2020-09-17  6449100
# 2020-09-18  8892600

# %%
def window_data(df, window, feature_col_number, target_col_number):
   
    X = []
    y = []
    for i in range(len(df) - window):
        features = amazon_df.iloc[i : (i + window), feature_col_number]
        target = amazon_df.iloc[(i + window), target_col_number]
        X.append(features)
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Creating the features (X) and target (y) data using the window_data() function.
window_size = 5

feature_column = 2
target_column = 2
X, y = window_data(amazon_df, window_size, feature_column, target_column)
print (f"X sample values:\n{X[:5]} \n")
print (f"y sample values:\n{y[:5]}")
# Out:
# X sample values:
# [[3096.       3108.919922 3074.149902 2972.550049 2905.540039]
#  [3108.919922 3074.149902 2972.550049 2905.540039 2871.      ]
#  [3074.149902 2972.550049 2905.540039 2871.       3000.199951]
#  [2972.550049 2905.540039 2871.       3000.199951 2992.379883]
#  [2905.540039 2871.       3000.199951 2992.379883 2965.      ]]
#
# y sample values:
# [[2871.      ]
#  [3000.199951]
#  [2992.379883]
#  [2965.      ]
#  [2999.      ]]

# %%
# Use 70% of the data for training and the remainder for testing
split = int(0.7 * len(X))
X_train = X[: split]
X_test = X[split:]
y_train = y[: split]
y_test = y[split:]

# %%
# Use the MinMaxScaler to scale data between 0 and 1.

scaler = MinMaxScaler()
scaler.fit(X)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
scaler.fit(y)
y_train = scaler.transform(y_train)
y_test = scaler.transform(y_test)

# %%
# Reshape the features for the model
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
print (f"X_train sample values:\n{X_train[:5]} \n")
print (f"X_test sample values:\n{X_test[:5]}")
# Out:
# X_train sample values:
# [[[0.27246635]
#   [0.28811188]
#   [0.24600672]
#   [0.12297321]
#   [0.04182666]]
#
#  [[0.28811188]
#   [0.24600672]
#   [0.12297321]
#   [0.04182666]
#   [0.        ]]
#
#  [[0.24600672]
#   [0.12297321]
#   [0.04182666]
#   [0.        ]
#   [0.15645618]]
#
#  [[0.12297321]
#   [0.04182666]
#   [0.        ]
#   [0.15645618]
#   [0.14698637]]
#
#  [[0.04182666]
#   [0.        ]
#   [0.15645618]
#   [0.14698637]
#   [0.11383039]]]
#
# X_test sample values:
# [[[0.39478559]
#   [0.41112145]
#   [0.4150692 ]
#   [0.46925973]
#   [0.43478369]]
#
#  [[0.41112145]
#   [0.4150692 ]
#   [0.46925973]
#   [0.43478369]
#   [0.42226224]]
#
#  [[0.4150692 ]
#   [0.46925973]
#   [0.43478369]
#   [0.42226224]
#   [0.40937774]]
#
#  [[0.46925973]
#   [0.43478369]
#   [0.42226224]
#   [0.40937774]
#   [0.40809405]]
#
#  [[0.43478369]
#   [0.42226224]
#   [0.40937774]
#   [0.40809405]
#   [0.37906733]]]

# %%
# Define the LSTM RNN model.
model = Sequential()

number_units = 5
dropout_fraction = 0.2

# Layer 1
model.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_train.shape[1], 1))
    )
model.add(Dropout(dropout_fraction))
# Layer 2
model.add(LSTM(units=number_units, return_sequences=True))
model.add(Dropout(dropout_fraction))
# Layer 3
model.add(LSTM(units=number_units))
model.add(Dropout(dropout_fraction))
# Output layer
model.add(Dense(1))

# %%
# Compile the model
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
# Summarize the model
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_3 (LSTM)                (None, 5, 5)              140
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 5)              0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 5, 5)              220
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 5, 5)              0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 5)                 220
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5)                 0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 6
# ...

# %%
# Train the model
model.fit(X_train, y_train, epochs=10, shuffle=False, batch_size=1, verbose=1)
# Out:
# Epoch 1/10
# 173/173 [==============================] - 7s 8ms/step - loss: 0.0460
# Epoch 2/10
# 173/173 [==============================] - 1s 8ms/step - loss: 0.0242
# Epoch 3/10
# 173/173 [==============================] - 2s 10ms/step - loss: 0.0234
# Epoch 4/10
# 173/173 [==============================] - 2s 10ms/step - loss: 0.0207
# Epoch 5/10
# 173/173 [==============================] - 2s 10ms/step - loss: 0.0196
# Epoch 6/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.0187
# Epoch 7/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.0207
# Epoch 8/10
# 173/173 [==============================] - 2s 10ms/step - loss: 0.0160
# Epoch 9/10
# 173/173 [==============================] - 2s 10ms/step - loss: 0.0165
# Epoch 10/10
# 173/173 [==============================] - 2s 10ms/step - loss: 0.0166

# %%
# Evaluate the model
model.evaluate(X_test, y_test)
# Out:
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0255
# 0.025504009798169136

# %%
# Make some predictions
predicted = model.predict(X_test)

# %%
# Recover the original prices instead of the scaled version
predicted_prices = scaler.inverse_transform(predicted)
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
# Create a DataFrame of Real and Predicted values
amazon_stocks = pd.DataFrame({
    "Real": real_prices.ravel(),
    "Predicted": predicted_prices.ravel()
    }, index = amazon_df.index[-len(real_prices): ])
amazon_stocks.head()
# Out:
#                    Real    Predicted
# Date
# 2021-05-28  3219.699951  3234.586670
# 2021-06-01  3209.060059  3239.740234
# 2021-06-02  3208.000000  3242.402100
# 2021-06-03  3184.030029  3243.821777
# 2021-06-04  3198.810059  3235.642578

# %%
# Plot the real vs predicted prices as a line chart
amazon_stocks.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Load the stocks data
nflx_df = pd.read_csv(
    Path("nflx.csv"),
    index_col="Date",
    infer_datetime_format=True,
    parse_dates=True,
)

# %%
def window_data(df, window, feature_col_number, target_col_number):
   
    X = []
    y = []
    for i in range(len(df) - window):
        features = df.iloc[i : (i + window), feature_col_number]
        target = df.iloc[(i + window), target_col_number]
        X.append(features)
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Creating the features (X) and target (y) data using the window_data() function.
window_size = 5

feature_column = 2
target_column = 2
X, y = window_data(nflx_df, window_size, feature_column, target_column)
print (f"X sample values:\n{X[:5]} \n")
print (f"y sample values:\n{y[:5]}")
# Out:
# X sample values:
# [[471.299988 481.630005 483.309998 463.269989 458.600006]
#  [481.630005 483.309998 463.269989 458.600006 466.320007]
#  [483.309998 463.269989 458.600006 466.320007 479.26001 ]
#  [463.269989 458.600006 466.320007 479.26001  469.      ]
#  [458.600006 466.320007 479.26001  469.       467.820007]]
#
# y sample values:
# [[466.320007]
#  [479.26001 ]
#  [469.      ]
#  [467.820007]
#  [468.029999]]

# %%
# Use 70% of the data for training and the remainder for testing
split = int(0.7 * len(X))
X_train = X[: split]
X_test = X[split:]
y_train = y[: split]
y_test = y[split:]

# %%
# Use the MinMaxScaler to scale data between 0 and 1.
scaler = MinMaxScaler()
scaler.fit(X)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
scaler.fit(y)
y_train = scaler.transform(y_train)
y_test = scaler.transform(y_test)

# %%
# Reshape the features for the model
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
print (f"X_train sample values:\n{X_train[:5]} \n")
print (f"X_test sample values:\n{X_test[:5]}")
# Out:
# X_train sample values:
# [[[0.09380297]
#   [0.1679673 ]
#   [0.17912284]
#   [0.03385273]
#   [0.        ]]
#
#  [[0.1701012 ]
#   [0.18022018]
#   [0.03385273]
#   [0.        ]
#   [0.05596232]]
#
#  [[0.18250975]
#   [0.03406012]
#   [0.        ]
#   [0.05596232]
#   [0.14976446]]
#
#  [[0.03449282]
#   [0.        ]
#   [0.05596232]
#   [0.14976446]
#   [0.0753896 ]]
#
#  [[0.        ]
#   [0.05630516]
#   [0.14976446]
#   [0.0753896 ]
#   [0.06683583]]]
#
# X_test sample values:
# [[[0.28554552]
#   [0.29837356]
#   [0.29445451]
#   [0.30373323]
#   [0.28952525]]
#
#  [[0.30216418]
#   [0.29625841]
#   [0.30373323]
#   [0.28952525]
#   [0.3184487 ]]
#
#  [[0.30002216]
#   [0.30559397]
#   [0.28952525]
#   [0.3184487 ]
#   [0.28372591]]
#
#  [[0.30947632]
#   [0.29129894]
#   [0.3184487 ]
#   [0.28372591]
#   [0.26980794]]
#
#  [[0.29499969]
#   [0.32039959]
#   [0.28372591]
#   [0.26980794]
#   [0.20768393]]]

# %%
# Define the LSTM RNN model.
model = Sequential()

number_units = 5
dropout_fraction = 0.2

# Layer 1
model.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_train.shape[1], 1))
    )
model.add(Dropout(dropout_fraction))
# Layer 2
model.add(LSTM(units=number_units, return_sequences=True))
model.add(Dropout(dropout_fraction))
# Layer 3
model.add(LSTM(units=number_units))
model.add(Dropout(dropout_fraction))
# Output layer
model.add(Dense(1))

# %%
# Compile the model
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
# Summarize the model
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_9 (LSTM)                (None, 5, 5)              140
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 5, 5)              0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 5, 5)              220
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 5, 5)              0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 5)                 220
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 5)                 0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 6
# ...

# %%
# Train the model
model.fit(X_train, y_train, epochs=10, shuffle=False, batch_size=1, verbose=1)
# Out:
# Epoch 1/10
# 173/173 [==============================] - 9s 9ms/step - loss: 0.0533
# Epoch 2/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.0382
# Epoch 3/10
# 173/173 [==============================] - 1s 9ms/step - loss: 0.0352
# Epoch 4/10
# 173/173 [==============================] - 1s 9ms/step - loss: 0.0300
# Epoch 5/10
# 173/173 [==============================] - 1s 9ms/step - loss: 0.0305
# Epoch 6/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.0255
# Epoch 7/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.0269
# Epoch 8/10
# 173/173 [==============================] - 1s 9ms/step - loss: 0.0252
# Epoch 9/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.0251
# Epoch 10/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.0240

# %%
# Evaluate the model
model.evaluate(X_test, y_test)
# Out:
# 3/3 [==============================] - 1s 6ms/step - loss: 0.0334
# 0.033438123762607574

# %%
# Make some predictions
predicted = model.predict(X_test)

# %%
# Recover the original prices instead of the scaled version
predicted_prices = scaler.inverse_transform(predicted)
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
# Create a DataFrame of Real and Predicted values
nflx_stocks = pd.DataFrame({
    "Real": real_prices.ravel(),
    "Predicted": predicted_prices.ravel()
    }, index = nflx_df.index[-len(real_prices): ])
nflx_stocks.head()
# Out:
#                   Real   Predicted
# Date
# 2021-05-28  502.529999  503.759827
# 2021-06-01  497.739990  504.133942
# 2021-06-02  495.820007  504.176361
# 2021-06-03  487.250000  504.192200
# 2021-06-04  490.950012  503.729340

# %%
# Plot the real vs predicted prices as a line chart
nflx_stocks.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Load the stocks data
tesla_df = pd.read_csv(
    Path("TSLA.csv"),
    index_col="Date",
    infer_datetime_format=True,
    parse_dates=True,
)
tesla_df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-09-14  380.950012  420.000000  373.299988  419.619995  419.619995
# 2020-09-15  436.559998  461.940002  430.700012  449.760010  449.760010
# 2020-09-16  439.869995  457.790009  435.309998  441.760010  441.760010
# 2020-09-17  415.600006  437.790009  408.000000  423.429993  423.429993
# 2020-09-18  447.940002  451.000000  428.799988  442.149994  442.149994
#
#               Volume
# Date
# 2020-09-14  83020600
# 2020-09-15  97298200
# 2020-09-16  72279300
# 2020-09-17  76779200
# 2020-09-18  86406800

# %%
def window_data(df, window, feature_col_number, target_col_number):
   
    X = []
    y = []
    for i in range(len(df) - window):
        features = df.iloc[i : (i + window), feature_col_number]
        target = df.iloc[(i + window), target_col_number]
        X.append(features)
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Creating the features (X) and target (y) data using the window_data() function.
window_size = 5

feature_column = 2
target_column = 2
X, y = window_data(tesla_df, window_size, feature_column, target_column)
print (f"X sample values:\n{X[:5]} \n")
print (f"y sample values:\n{y[:5]}")
# Out:
# X sample values:
# [[373.299988 430.700012 435.309998 408.       428.799988]
#  [430.700012 435.309998 408.       428.799988 407.070007]
#  [435.309998 408.       428.799988 407.070007 417.600006]
#  [408.       428.799988 407.070007 417.600006 375.880005]
#  [428.799988 407.070007 417.600006 375.880005 351.299988]]
#
# y sample values:
# [[407.070007]
#  [417.600006]
#  [375.880005]
#  [351.299988]
#  [391.299988]]

# %%
# Use 70% of the data for training and the remainder for testing
split = int(0.7 * len(X))
X_train = X[: split]
X_test = X[split:]
y_train = y[: split]
y_test = y[split:]

# %%
scaler = MinMaxScaler()
scaler.fit(X)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
scaler.fit(y)
y_train = scaler.transform(y_train)
y_test = scaler.transform(y_test)

# %%
# Reshape the features for the model
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
print (f"X_train sample values:\n{X_train[:5]} \n")
print (f"X_test sample values:\n{X_test[:5]}")
# Out:
# X_train sample values:
# [[[0.0422833 ]
#   [0.15260432]
#   [0.16146456]
#   [0.10897562]
#   [0.14895253]]
#
#  [[0.15260432]
#   [0.16146456]
#   [0.10897562]
#   [0.14895253]
#   [0.1071882 ]]
#
#  [[0.16146456]
#   [0.10897562]
#   [0.14895253]
#   [0.1071882 ]
#   [0.12742652]]
#
#  [[0.10897562]
#   [0.14895253]
#   [0.1071882 ]
#   [0.12742652]
#   [0.04724201]]
#
#  [[0.14895253]
#   [0.1071882 ]
#   [0.12742652]
#   [0.04724201]
#   [0.        ]]]
#
# X_test sample values:
# [[[0.43955414]
#   [0.42734969]
#   [0.4697483 ]
#   [0.48087645]
#   [0.50914865]]
#
#  [[0.42734969]
#   [0.4697483 ]
#   [0.48087645]
#   [0.50914865]
#   [0.52100716]]
#
#  [[0.4697483 ]
#   [0.48087645]
#   [0.50914865]
#   [0.52100716]
#   [0.51748992]]
#
#  [[0.48087645]
#   [0.50914865]
#   [0.52100716]
#   [0.51748992]
#   [0.47634064]]
#
#  [[0.50914865]
#   [0.52100716]
#   [0.51748992]
#   [0.47634064]
#   [0.4226792 ]]]

# %%
# Define the LSTM RNN model.
model = Sequential()

number_units = 5
dropout_fraction = 0.2

# Layer 1
model.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_train.shape[1], 1))
    )
model.add(Dropout(dropout_fraction))
# Layer 2
model.add(LSTM(units=number_units, return_sequences=True))
model.add(Dropout(dropout_fraction))
# Layer 3
model.add(LSTM(units=number_units))
model.add(Dropout(dropout_fraction))
# Output layer
model.add(Dense(1))

# %%
# Compile the model
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
# Summarize the model
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_12 (LSTM)               (None, 5, 5)              140
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 5, 5)              0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 5, 5)              220
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 5, 5)              0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 5)                 220
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 5)                 0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 6
# ...

# %%
# Train the model
model.fit(X_train, y_train, epochs=10, shuffle=False, batch_size=1, verbose=1)
# Out:
# Epoch 1/10
# 173/173 [==============================] - 9s 10ms/step - loss: 0.0541
# Epoch 2/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.0604
# Epoch 3/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.0541
# Epoch 4/10
# 173/173 [==============================] - 2s 9ms/step - loss: 0.0460
# Epoch 5/10
# 173/173 [==============================] - 2s 10ms/step - loss: 0.0383
# Epoch 6/10
# 173/173 [==============================] - 2s 10ms/step - loss: 0.0283
# Epoch 7/10
# 173/173 [==============================] - 2s 10ms/step - loss: 0.0325
# Epoch 8/10
# 173/173 [==============================] - 2s 11ms/step - loss: 0.0279
# Epoch 9/10
# 173/173 [==============================] - 2s 11ms/step - loss: 0.0277
# Epoch 10/10
# 173/173 [==============================] - 2s 10ms/step - loss: 0.0270

# %%
# Evaluate the model
model.evaluate(X_test, y_test)
# Out:
# 3/3 [==============================] - 2s 6ms/step - loss: 0.0050
# 0.0049651144072413445

# %%
# Make some predictions
predicted = model.predict(X_test)

# %%
# Create a DataFrame of Real and Predicted values
tesla_stocks = pd.DataFrame({
    "Real": real_prices.ravel(),
    "Predicted": predicted_prices.ravel()
    }, index = tesla_df.index[-len(real_prices): ])
tesla_stocks.head()
# Out:
#                   Real   Predicted
# Date
# 2021-05-28  502.529999  503.759827
# 2021-06-01  497.739990  504.133942
# 2021-06-02  495.820007  504.176361
# 2021-06-03  487.250000  504.192200
# 2021-06-04  490.950012  503.729340

# %%
# Plot the real vs predicted prices as a line chart
tesla_stocks.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
